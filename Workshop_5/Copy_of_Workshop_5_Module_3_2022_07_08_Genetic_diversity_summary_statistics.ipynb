# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanuelwanyama/INTERNSHIP_2023/blob/main/Workshop_5/Copy_of_Workshop_5_Module_3_2022_07_08_Genetic_diversity_summary_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![banner](https://github.com/anopheles-genomic-surveillance/anopheles-genomic-surveillance.github.io/blob/master/docs/banner.jpg?raw=1)
#
# ***[Workshop 5](about) - Training course in data analysis for genomic surveillance of African malaria vectors***
#
# ---

# %% [markdown]
# # Module 3 - Genetic diversity summary statistics
#
# **Theme: Analysis**
#
# This module covers how to compute genetic diversity summary statistics, which are a convenient and informative way to quantify and compare diversity in different mosquito populations.

# %% [markdown]
# ## Learning objectives
#
# At the end of this module you will be able to:
#
# * Select cohorts for comparative analysis of genetic diversity
# * Compute nucleotide diversity, Watterson's estimator and Tajima's D
# * Plot diversity statistics for multiple cohorts
# * Interpret the results

# %% [markdown]
# ## Lecture

# %% [markdown]
# ### English

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ohKfiu_WC-g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ohKfiu_WC-g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Français

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/pkwpz8cWp44" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/pkwpz8cWp44" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Please note that the code in the cells below might differ from that shown in the video. This can happen because Python packages and their dependencies change due to updates, necessitating tweaks to the code.

# %% [markdown]
# ## Setup
#
# Install and import the packages we'll need.

# %%
# !pip install -q --no-warn-conflicts malariagen_data
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 63.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 55.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.5/302.5 kB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 43.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.5 MB/s eta 0:00:00
#   Building wheel for asciitree (setup.py) ... done

# %%
import malariagen_data
import plotly.express as px

# %% [markdown]
# Here we will compute summary statistics using data from millions of SNPs. This can take some time, so we will use Google Drive to save results and avoid having to rerun computations. To do this we first need to mount Google Drive to our colab VM:

# %%
try:
    from google.colab import drive
    drive.mount("drive")
except ImportError:
    pass
# Out:
# Mounted at drive

# %% [markdown]
# Configure access to MalariaGEN data in Google Cloud.

# %%
ag3 = malariagen_data.Ag3(
    results_cache="drive/MyDrive/malariagen_data_cache"
)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release/
# Data releases available : 3.0
# Results cache           : /content/drive/MyDrive/malariagen_data_cache
# Cohorts analysis        : 20230516
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.12.0
# Client location         : Washington, D.C., US
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %% [markdown]
# ## Selecting cohorts
#
# In this module we will be comparing genetic diversity between mosquitoes representing different geographical locations, time points and species. Before we begin any comparative analysis of genetic diversity, we first need to decide how to group the mosquitoes we've sequenced into cohorts. Each cohort we define will represent a sample of mosquitoes from a given time, place and species.
#
# Let's first browse the different sample locations for which we have data. In [workshop 1, module 2](https://anopheles-genomic-surveillance.github.io/workshop-1/module-2-sample-metadata.html) we looked at how to create an interactive map with sampling locations using ipyleaflet. Because this is something we want to do often, we've added a convenience function `plot_samples_interactive_map()` to do this for you. This will plot a map showing sampling locations for all available samples.

# %%
ag3.plot_samples_interactive_map()
# Out:
# Map(center=[-2, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# For the purposes of this module we will begin by focusing on Tanzania. To get more information on the numbers of samples available from Tanzania, we can use pandas to create a pivot table as we also illustrated in [workshop 1, module 2](https://anopheles-genomic-surveillance.github.io/workshop-1/module-2-sample-metadata.html). Again, because we do this often, we've created a convenience function `count_samples()`.

# %%
ag3.count_samples(
    sample_query="country == 'Tanzania'"
)
# Out:
# taxon                                             arabiensis  gambiae  gcx3
# country  admin1_iso admin1_name admin2_name year
# Tanzania TZ-05      Kagera      Muleba      2015         137       32     1
#          TZ-13      Mara        Tarime      2012          47        0     0
#          TZ-25      Tanga       Muheza      2013           1       32    10
#          TZ-26      Manyara     Moshi       2012          40        0     0

# %% [markdown]
# When grouping samples by geographical location, we sometimes can choose whether to aggregate data from nearby locations, or whether to keep them separate. In general, we want the finest spatial granularity possible, but we also need enough samples to make reasonable estimates of genetic diversity, and so we might have to make a trade-off between granularity and sample size.
#
# Similarly, when grouping samples by date of collection, we can choose whether to aggregate data from the same month, season or year. Again, in general we would prefer the finest temporal granularity possible, but might also need sufficient sample size.
#
# For computing diversity summary statistics, there is no hard-and-fast rule about how many samples are needed, but a sample size of 10 is probably the bare minimum we would consider, and we would prefer more if possible.
#
# To simplify grouping of mosquitoes into cohorts, we have predefined some metadata columns which provide cohort labels at different levels of granularity. Let's take a peek at the sample metadata:

# %%
df_samples_tz = ag3.sample_metadata(
    sample_query="country == 'Tanzania'"
)
df_samples_tz.head()
# Out:
#   sample_id partner_sample_id    contributor   country location  year  month  \
# 0  BL0046-C        Plate_C_H6  Bilali Kabula  Tanzania   Muleba  2015      6
# 1  BL0047-C        Plate_F_D4  Bilali Kabula  Tanzania   Muleba  2015      3
# 2  BL0048-C        Plate_F_E4  Bilali Kabula  Tanzania   Muleba  2015      3
# 3  BL0049-C        Plate_F_F4  Bilali Kabula  Tanzania   Muleba  2015      3
# 4  BL0050-C        Plate_F_G4  Bilali Kabula  Tanzania   Muleba  2015      3
#
#    latitude  longitude sex_call  ... admin1_name admin1_iso  admin2_name  \
# 0    -1.962     31.621        F  ...      Kagera      TZ-05       Muleba
# 1    -1.962     31.621        F  ...      Kagera      TZ-05       Muleba
# 2    -1.962     31.621        F  ...      Kagera      TZ-05       Muleba
# 3    -1.962     31.621        F  ...      Kagera      TZ-05       Muleba
# 4    -1.962     31.621        F  ...      Kagera      TZ-05       Muleba
#
#         taxon  cohort_admin1_year  cohort_admin1_month cohort_admin1_quarter  \
# 0        gcx3     TZ-05_gcx3_2015   TZ-05_gcx3_2015_06    TZ-05_gcx3_2015_Q2
# 1  arabiensis     TZ-05_arab_2015   TZ-05_arab_2015_03    TZ-05_arab_2015_Q1
# 2  arabiensis     TZ-05_arab_2015   TZ-05_arab_2015_03    TZ-05_arab_2015_Q1
# 3  arabiensis     TZ-05_arab_2015   TZ-05_arab_2015_03    TZ-05_arab_2015_Q1
# 4  arabiensis     TZ-05_arab_2015   TZ-05_arab_2015_03    TZ-05_arab_2015_Q1
#
#        cohort_admin2_year        cohort_admin2_month  \
# 0  TZ-05_Muleba_gcx3_2015  TZ-05_Muleba_gcx3_2015_06
# 1  TZ-05_Muleba_arab_2015  TZ-05_Muleba_arab_2015_03
# 2  TZ-05_Muleba_arab_2015  TZ-05_Muleba_arab_2015_03
# 3  TZ-05_Muleba_arab_2015  TZ-05_Muleba_arab_2015_03
# 4  TZ-05_Muleba_arab_2015  TZ-05_Muleba_arab_2015_03
#
#        cohort_admin2_quarter
# 0  TZ-05_Muleba_gcx3_2015_Q2
# 1  TZ-05_Muleba_arab_2015_Q1
# 2  TZ-05_Muleba_arab_2015_Q1
# 3  TZ-05_Muleba_arab_2015_Q1
# 4  TZ-05_Muleba_arab_2015_Q1
#
# [5 rows x 30 columns]

# %% [markdown]
# If you scroll to the right, you'll see columns named "cohort_admin1_year", "cohort_admin1_month", "cohort_admin2_year" and "cohort_admin2_month". Each of these columns provides a different set of cohort labels. All are grouped by species (taxon).
#
# For this analysis, let's use the "cohort_admin2_year" column to group samples by administrative level 2 divisions (usually called districts) and year. Here are the cohort labels for the Tanzania samples and the sample sizes.

# %%
df_samples_tz.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# TZ-05_Muleba_arab_2015    137
# TZ-05_Muleba_gamb_2015     32
# TZ-05_Muleba_gcx3_2015      1
# TZ-13_Tarime_arab_2012     47
# TZ-25_Muheza_arab_2013      1
# TZ-25_Muheza_gamb_2013     32
# TZ-25_Muheza_gcx3_2013     10
# TZ-26_Moshi_arab_2012      40
# dtype: int64

# %% [markdown]
# We can see there are two cohorts with only 1 sample - these will get dropped from our analysis. Otherwise, all cohorts have at least 10 samples.

# %% [markdown]
# ## Recap: genetic diversity summary statistics
#
# We are going to compute the following three summary statistics for each cohort:
#
# * Nucleotide diversity (`theta_pi`) - This quantifies the average number of differences (mismatches) between any pair of DNA sequences in a cohort. The higher this statistic, the more differences you will expect to see between any pair of randomly sampled DNA sequences.
# * Watterson's estimator (`theta_w`) - This quantifies the number of segregating sites within a cohort, scaled by a constant. The higher this statistic, the more sites are found to be segregating (i.e., polymorphic).
# * Tajima's D (`tajima_d`) - This quantifies the difference between Watterson's estimator and nucleotide diversity, and scales the result by a constant. This statistic is useful because it focuses not on the magnitude but on the architecture of diversity in a cohort, compared to a neutrally evolving population of constant size. Negative values imply an excess of rare alleles, and positive values imply a deficit of rare alleles, relative to a population at equilibrium.

# %% [markdown]
# ## Computing diversity summary statistics
#
# Let's begin by computing these summary statistics in a single cohort. For this we can use the function `cohort_diversity_stats()`. Let's look at the docstring.

# %%
ag3.cohort_diversity_stats?

# %% [markdown]
# Let's now compute the statistics for one of our Tanzanian cohorts, TZ-05_Muleba_gamb_2015.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=30,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
stats
# Out:
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.021167
# theta_pi_estimate                  0.021173
# theta_pi_bias                     -0.000005
# theta_pi_std_err                     0.0003
# theta_pi_ci_err                    0.001176
# theta_pi_ci_low                    0.020585
# theta_pi_ci_upp                    0.021761
# theta_w                            0.038855
# theta_w_estimate                   0.038854
# theta_w_bias                       0.000001
# theta_w_std_err                    0.000436
# theta_w_ci_err                     0.001709
# theta_w_ci_low                     0.037999
# theta_w_ci_upp                     0.039708
# tajima_d                          -1.635894
# tajima_d_estimate                 -1.635436
# tajima_d_bias                     -0.000459
# tajima_d_std_err                   0.015294
# tajima_d_ci_err                     0.05995
# tajima_d_ci_low                   -1.665411
# tajima_d_ci_upp                   -1.605461
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# This function returns a pandas Series with values of the summary statistics for our requested cohort. The field `theta_pi` contains the value of nucleotide diversity. The field `theta_w` contains the value of Watterson's estimator. The field `tajima_d` contains the value of Tajima's D.
#
# A 95% confidence interval has also been estimated for each of these statistics using a block jackknife procedure. The lower and upper ends of these confidence intervals are given by the fields with the suffixes `_ci_low` and `_ci_upp` respectively. The fields with suffix `_ci_err` give the size of the confidence interval, and is useful for plotting error bars.
#
# It is important to note that, in addition to the `cohort` parameter, we also provided values for the parameters `cohort_size`, `region`, `site_mask` and `site_class`. These parameters are important and can make a big difference to the statistic values obtained.
#
# To illustrate the impact of changing some of these parameters, let's recompute the statistics but providing `cohort_size` of 10 instead of 30.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
stats
# Out:
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.021242
# theta_pi_estimate                  0.021247
# theta_pi_bias                     -0.000004
# theta_pi_std_err                   0.000302
# theta_pi_ci_err                    0.001182
# theta_pi_ci_low                    0.020655
# theta_pi_ci_upp                    0.021838
# theta_w                             0.03035
# theta_w_estimate                   0.030352
# theta_w_bias                      -0.000003
# theta_w_std_err                    0.000377
# theta_w_ci_err                     0.001478
# theta_w_ci_low                     0.029613
# theta_w_ci_upp                     0.031092
# tajima_d                          -1.259672
# tajima_d_estimate                 -1.259398
# tajima_d_bias                     -0.000274
# tajima_d_std_err                   0.016672
# tajima_d_ci_err                    0.065353
# tajima_d_ci_low                   -1.292075
# tajima_d_ci_upp                   -1.226721
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# Note that the value of `theta_pi` hasn't changed much, but the values of `theta_w` and `tajima_d` are considerably different. This is because, for many cohorts, there is a strong dependency between these statistics and the cohort size, i.e., the number of samples used to calculate the statistics. Because of this, if we want to make a fair comparison between different cohorts, it is important to use the same cohort size in all cases. If we have a cohort with more samples than our chosen cohort size, the cohort will be randomly downsampled.
#
# Another parameter that makes a big difference is the `site_class` parameter, which defines the type of genomic site used to calculate the diversity statistics. Above we used "CDS_DEG_4" which stands for [4-fold degenerate coding sites](https://en.wikipedia.org/wiki/Codon_degeneracy), i.e., sites within gene coding sequences where none of the possible nucleotide changes will affect the resulting amino acid. These sites are typically under relatively weak selective constraint, because they have little to no impact on the phenotype of the organism.
#
# For illustration, let's contrast this with "CDS_DEG_0" which stands for non-degenerate coding sites, i.e., sites where any nucleotide change will change the amino acid.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_0",
)
stats
# Out:
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.002492
# theta_pi_estimate                  0.002492
# theta_pi_bias                          -0.0
# theta_pi_std_err                   0.000091
# theta_pi_ci_err                    0.000356
# theta_pi_ci_low                    0.002314
# theta_pi_ci_upp                     0.00267
# theta_w                            0.004047
# theta_w_estimate                   0.004047
# theta_w_bias                      -0.000001
# theta_w_std_err                     0.00013
# theta_w_ci_err                     0.000509
# theta_w_ci_low                     0.003793
# theta_w_ci_upp                     0.004302
# tajima_d                          -1.612858
# tajima_d_estimate                 -1.612861
# tajima_d_bias                      0.000004
# tajima_d_std_err                   0.026732
# tajima_d_ci_err                    0.104788
# tajima_d_ci_low                   -1.665255
# tajima_d_ci_upp                   -1.560467
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# Note that the value of `theta_pi` has now reduced by approximately an order of magnitude. This is because non-degenerate coding sites are subject to much stronger purifying selection than 4-fold degenerate sites.
#
# In this module we are most interested in using comparative analysis of diversity statistics to learn more about demographic differences and changes within our sampled mosquito populations. Hence we will prefer to use sites that are less affected by selection, and will use 4-fold degenerate sites ("CDS_DEG_4") for the remainder of the module.
#
# A final note, above we chose to provide the parameter `region="3L:15,000,000-41,000,000"`, which defines the genome region we will use for diversity calculations. We typically prefer to use chromosome arm 3L because there are no large polymorphic inversions in any of the species we are studying. We also exclude the pericentromeric and telomeric regions because these have reduced diversity due to reduced recombination and hence selection at linked sites.

# %% [markdown]
# ## Comparing diversity between cohorts
#
# Now we have seen how to compute statistics for a single cohort, let's run the same computation but for multiple cohorts, and see how to compare the results.

# %% [markdown]
# ### Example: Tanzania
#
# Sticking with our focus on Tanzania, let's remind ourselves what cohorts and sample sizes are available if we group samples by the "cohort_admin2_year" field, which will group by taxon, district and year.

# %%
df_samples_tz.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# TZ-05_Muleba_arab_2015    137
# TZ-05_Muleba_gamb_2015     32
# TZ-05_Muleba_gcx3_2015      1
# TZ-13_Tarime_arab_2012     47
# TZ-25_Muheza_arab_2013      1
# TZ-25_Muheza_gamb_2013     32
# TZ-25_Muheza_gcx3_2013     10
# TZ-26_Moshi_arab_2012      40
# dtype: int64

# %% [markdown]
# If we choose a cohort size of 10 for our comparative analysis, we will be able to analyse 6 cohorts.
#
# To compute diversity for multiple cohorts at the same time, we have provided a `diversity_stats()` function.

# %%
ag3.diversity_stats?

# %% [markdown]
# This function has many of the same parameters we discussed above, except now we provide a `sample_query` parameter to restrict the overall analysis to samples in Tanzania, and we provide a `cohorts` parameter to define how these samples will be grouped into cohorts.

# %%
df_stats_tz_admin2_year = ag3.diversity_stats(
    sample_query="country == 'Tanzania'",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_tz_admin2_year
# Out:
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
#                    cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0  TZ-05_Muleba_arab_2015  0.012306           0.012306   6.185033e-07
# 1  TZ-05_Muleba_gamb_2015  0.021242           0.021247  -4.337053e-06
# 2  TZ-13_Tarime_arab_2012  0.012435           0.012435  -3.120599e-07
# 3  TZ-25_Muheza_gamb_2013  0.017705           0.017705   4.563558e-07
# 4  TZ-25_Muheza_gcx3_2013  0.013395           0.013398  -2.958723e-06
# 5   TZ-26_Moshi_arab_2012  0.012374           0.012373   1.310417e-06
#
#    theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0          0.000224         0.000877         0.011867         0.012744
# 1          0.000302         0.001182         0.020655         0.021838
# 2          0.000220         0.000861         0.012005         0.012866
# 3          0.000290         0.001136         0.017137         0.018273
# 4          0.000342         0.001340         0.012728         0.014068
# 5          0.000219         0.000857         0.011945         0.012801
#
#     theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0  0.014789          0.014790  ...        -0.658653  arabiensis  2015
# 1  0.030350          0.030352  ...        -1.226721     gambiae  2015
# 2  0.015058          0.015059  ...        -0.681130  arabiensis  2012
# 3  0.018939          0.018935  ...        -0.218096     gambiae  2013
# 4  0.012917          0.012918  ...         0.257321        gcx3  2013
# 5  0.014669          0.014667  ...        -0.604319  arabiensis  2012
#
#        month   country  admin1_iso  admin1_name  admin2_name  longitude  \
# 0  [3, 4, 6]  Tanzania       TZ-05       Kagera       Muleba     31.621
# 1     [3, 6]  Tanzania       TZ-05       Kagera       Muleba     31.621
# 2          8  Tanzania       TZ-13         Mara       Tarime     34.199
# 3          1  Tanzania       TZ-25        Tanga       Muheza     38.948
# 4          1  Tanzania       TZ-25        Tanga       Muheza     38.948
# 5          8  Tanzania       TZ-26      Manyara        Moshi     37.308
#
#    latitude
# 0    -1.962
# 1    -1.962
# 2    -1.431
# 3    -4.940
# 4    -4.940
# 5    -3.482
#
# [6 rows x 31 columns]

# %% [markdown]
# This function returns a pandas DataFrame, where each row contains data about a cohort, and the columns provide the different statistic values and their confidence intervals. Let's take a look at all the available columns:

# %%
df_stats_tz_admin2_year.columns
# Out:
# Index(['cohort', 'theta_pi', 'theta_pi_estimate', 'theta_pi_bias',
#        'theta_pi_std_err', 'theta_pi_ci_err', 'theta_pi_ci_low',
#        'theta_pi_ci_upp', 'theta_w', 'theta_w_estimate', 'theta_w_bias',
#        'theta_w_std_err', 'theta_w_ci_err', 'theta_w_ci_low', 'theta_w_ci_upp',
#        'tajima_d', 'tajima_d_estimate', 'tajima_d_bias', 'tajima_d_std_err',
#        'tajima_d_ci_err', 'tajima_d_ci_low', 'tajima_d_ci_upp', 'taxon',
#        'year', 'month', 'country', 'admin1_iso', 'admin1_name', 'admin2_name',
#        'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# A simple way to visualise these statistics and compare cohorts is to make a bar plot. Let's do this for nucleotide diversity using plotly express.

# %%
px.bar(
    data_frame=df_stats_tz_admin2_year,
    x="cohort",
    y="theta_pi_estimate",
    error_y="theta_pi_ci_err",
    color="taxon",
    height=450,
    width=500,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8b25ddc1-aaa8-4ada-9c2b-8e15f9867764" class="plotly-graph-div" style="height:450px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b25ddc1-aaa8-4ada-9c2b-8e15f9867764")) {                    Plotly.newPlot(                        "8b25ddc1-aaa8-4ada-9c2b-8e15f9867764",                        [{"alignmentgroup":"True","error_y":{"array":[0.0008767828578080529,0.0008610896628349071,0.0008565317306298919]},"hovertemplate":"taxon=arabiensis<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0011824588643770378,0.0011361997218875947]},"hovertemplate":"taxon=gambiae<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.021246519681427135,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.001340143471567124]},"hovertemplate":"taxon=gcx3<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %% [markdown]
# Above we chose to colour the bars by taxon, which helps to see some of the patterns in the data. For example, we have three *An. arabiensis* cohorts, all of which have nearly identical nucleotide diversity. We also have two *An. gambiae* cohorts, both of which have higher nucleotide diversity. There is also a significant difference between the two *An. gambiae* cohorts from the east and west of the country. Finally, we have one cohort representing the putative cryptic taxon which we have provisionally labelled gcx3 (see [workshop 4, module 4](https://anopheles-genomic-surveillance.github.io/workshop-4/module-4-taxon-analysis.html)).
#
# We also would like to make similar plots to visualise Watterson's estimator and Tajima's D. Because we'll want to make these plots often, let's define a simple function to make all the plots we need.

# %%
def plot_diversity_stats(
    df_stats,
    color=None,
    height=450,
    template="plotly_white"
):

    # set up common plotting parameters
    hover_name = "cohort"
    hover_data = [
        "taxon",
        "country",
        "admin1_iso",
        "admin1_name",
        "admin2_name",
        "year",
        "month",
    ]
    labels = {
        'theta_pi_estimate': r'$\widehat{\theta}_{\pi}$',
        'theta_w_estimate': r'$\widehat{\theta}_{w}$',
        'tajima_d_estimate': r'$D$',
        'cohort': "Cohort",
        'taxon': 'Taxon',
        'country': "Country",
    }
    category_orders = {
        "taxon": ["arabiensis", "gambiae", "gcx3", "coluzzii", "gcx1", "gcx2"],
    }
    width = 300 + 30 * len(df_stats)

    # nucleotide diversity bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_pi_estimate",
        error_y="theta_pi_ci_err",
        title="Nucleotide diversity",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # watterson estimator bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_w_estimate",
        error_y="theta_w_ci_err",
        title="Watterson estimator",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # tajima's d bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="tajima_d_estimate",
        error_y="tajima_d_ci_err",
        title="Tajima's D",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # scatter plot comparing diversity estimators
    fig = px.scatter(
        data_frame=df_stats,
        x="theta_pi_estimate",
        y="theta_w_estimate",
        error_x="theta_pi_ci_err",
        error_y="theta_w_ci_err",
        title="Diversity estimators",
        color=color,
        width=500,
        height=500,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

# %% [markdown]
# Let's now make these plots for our Tanzanian cohorts.

# %%
plot_diversity_stats(df_stats_tz_admin2_year, color="taxon")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="48ba2510-71c0-4593-bc07-07aaa70bcfa7" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48ba2510-71c0-4593-bc07-07aaa70bcfa7")) {                    Plotly.newPlot(                        "48ba2510-71c0-4593-bc07-07aaa70bcfa7",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0008767828578080529,0.0008610896628349071,0.0008565317306298919]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0011824588643770378,0.0011361997218875947]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.021246519681427135,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.001340143471567124]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="80718370-0c2e-4839-9fab-93376b4602ab" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80718370-0c2e-4839-9fab-93376b4602ab")) {                    Plotly.newPlot(                        "80718370-0c2e-4839-9fab-93376b4602ab",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0009732513776216025,0.000970944204637161,0.0009124973674744431]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.01479018822563256,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0014784123971940866,0.0011770314504906054]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.030352491386682584,0.018935395054669256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="184a0952-c927-45b8-ae84-6a1fbbbaac1b" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("184a0952-c927-45b8-ae84-6a1fbbbaac1b")) {                    Plotly.newPlot(                        "184a0952-c927-45b8-ae84-6a1fbbbaac1b",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.09298333949876054,0.10060131875886641,0.1045317786377764]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[-0.7051445660180288,-0.7314308240562268,-0.6565852582790553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.06535341551175325,0.10950056994601906]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[-1.2593981283459053,-0.2728466026281025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.2021446790128285]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.15624830920460062],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="01f3dff4-4a8e-425f-ac54-f3cc17c35735" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01f3dff4-4a8e-425f-ac54-f3cc17c35735")) {                    Plotly.newPlot(                        "01f3dff4-4a8e-425f-ac54-f3cc17c35735",                        [{"customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_x":{"array":[0.0008767828578080529,0.0008610896628349071,0.0008565317306298919]},"error_y":{"array":[0.0009732513776216025,0.000970944204637161,0.0009124973674744431]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"xaxis":"x","y":[0.01479018822563256,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0011824588643770378,0.0011361997218875947]},"error_y":{"array":[0.0014784123971940866,0.0011770314504906054]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021246519681427135,0.01770499150805352],"xaxis":"x","y":[0.030352491386682584,0.018935395054669256],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.001340143471567124]},"error_y":{"array":[0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"gcx3","orientation":"v","showlegend":true,"x":[0.013397633291510242],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type" ...

# %% [markdown]
# From the above we can see the following patterns:
#
# * All *An. arabiensis* cohorts have similar diversity, regardless of sampling location.
# * *An. gambiae* cohorts have different diversity between the west and east of the country.
# * The gcx3 cohort is quite different from all other cohorts, and is the only cohort with a positive value for Tajima's D.

# %% [markdown]
# **Exercise 1 (English)**
#
# Uncomment and run the code cells below to repeat the above analysis, but using cohorts grouped by district (administrative level 2) and month.
#
# Do the results change any of our observations about the similarities and differences between species and geographical locations?
#
# Is there any evidence for differences in diversity between different months of sampling?
#
# **Exercice 1 (Français)**
#
# Décommentez et exécutez les cellules de code ci-dessous pour répéter l'analyse ci-dessus, mais en utilisant des cohortes regroupées par district (niveau administratif 2) et mois.
#
# Les résultats modifient-ils certaines de nos observations sur les similitudes et les différences entre les espèces et les emplacements géographiques?
#
# Existe-t-il des preuves de différences de diversité entre les différents mois d'échantillonnage?

# %%
 df_samples_tz.groupby("cohort_admin2_month").size()
# Out:
# cohort_admin2_month
# TZ-05_Muleba_arab_2015_03    39
# TZ-05_Muleba_arab_2015_04    10
# TZ-05_Muleba_arab_2015_06    88
# TZ-05_Muleba_gamb_2015_03    13
# TZ-05_Muleba_gamb_2015_06    19
# TZ-05_Muleba_gcx3_2015_06     1
# TZ-13_Tarime_arab_2012_08    47
# TZ-25_Muheza_arab_2013_01     1
# TZ-25_Muheza_gamb_2013_01    32
# TZ-25_Muheza_gcx3_2013_01    10
# TZ-26_Moshi_arab_2012_08     40
# dtype: int64

# %%
 df_stats_tz_admin2_month = ag3.diversity_stats(
     sample_query="country == 'Tanzania'",
     cohorts="admin2_month",
     cohort_size=10,
     region="3L:15,000,000-41,000,000",
     site_mask="gamb_colu_arab",
     site_class="CDS_DEG_4",
 )
 plot_diversity_stats(df_stats_tz_admin2_month, color="taxon")
# Out:
# [INFO] cohort (TZ-05_Muleba_gcx3_2015_06) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-05_Muleba_gcx3_2015_06) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013_01) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-25_Muheza_arab_2013_01) has insufficient samples (1) for requested cohort size (10), dropping
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="21a832c1-22af-401f-a02d-08ce3c07dfb3" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21a832c1-22af-401f-a02d-08ce3c07dfb3")) {                    Plotly.newPlot(                        "21a832c1-22af-401f-a02d-08ce3c07dfb3",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0008502917024697049,0.000878233569925899,0.000854413045125332,0.0008610896628349071,0.0008565317306298919]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[0.012479393110095556,0.012496682440614283,0.01246700705892751,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0012323801448479372,0.0011987292006040851,0.0011361997218875947]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[0.021195452007257518,0.02106752800925177,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.001340143471567124]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d8567d6d-d462-4ea5-94b2-a9b18a0d2bbe" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8567d6d-d462-4ea5-94b2-a9b18a0d2bbe")) {                    Plotly.newPlot(                        "d8567d6d-d462-4ea5-94b2-a9b18a0d2bbe",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0009197371951446739,0.0009164167717643277,0.000962186343263365,0.000970944204637161,0.0009124973674744431]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[0.01513110931443085,0.015042961968913951,0.015178903760198445,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0015808495171566396,0.0015202771056640272,0.0011770314504906054]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[0.030066798480798327,0.029694017681851693,0.018935395054669256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="580abc2f-d5b2-4ff5-9d70-9cb3d95929b3" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("580abc2f-d5b2-4ff5-9d70-9cb3d95929b3")) {                    Plotly.newPlot(                        "580abc2f-d5b2-4ff5-9d70-9cb3d95929b3",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.10292578182908278,0.09498672133617583,0.10049480637627262,0.10060131875886641,0.1045317786377764]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[-0.7356829936003861,-0.7105225757067777,-0.7500368118206585,-0.7314308240562268,-0.6565852582790553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.06431914522687797,0.06680181414423514,0.10950056994601906]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[-1.2386145394374024,-1.219550866059332,-0.2728466026281025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.2021446790128285]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.15624830920460062],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"ov ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7f6396ee-0059-41b4-9459-24705bbc9258" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f6396ee-0059-41b4-9459-24705bbc9258")) {                    Plotly.newPlot(                        "7f6396ee-0059-41b4-9459-24705bbc9258",                        [{"customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_x":{"array":[0.0008502917024697049,0.000878233569925899,0.000854413045125332,0.0008610896628349071,0.0008565317306298919]},"error_y":{"array":[0.0009197371951446739,0.0009164167717643277,0.000962186343263365,0.000970944204637161,0.0009124973674744431]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.012479393110095556,0.012496682440614283,0.01246700705892751,0.012435191358870714,0.012372971080334862],"xaxis":"x","y":[0.01513110931443085,0.015042961968913951,0.015178903760198445,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0012323801448479372,0.0011987292006040851,0.0011361997218875947]},"error_y":{"array":[0.0015808495171566396,0.0015202771056640272,0.0011770314504906054]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021195452007257518,0.02106752800925177,0.01770499150805352],"xaxis":"x","y":[0.030066798480798327,0.029694017681851693,0.018935395054669256],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.001340143471567124]},"error_y":{"array":[0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"gcx3","orientation":"v","showlegend":true,"x":[0.013397633291510242],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay", ...

# %% [markdown]
# ### Example: East Africa
#
# Let's now expand our analysis to include samples from neighbouring countries, to investigate a broader geographical range.
#
# Firstly, let's plot a map to remind ourselves of the available sampling locations.

# %%
ag3.plot_samples_interactive_map()
# Out:
# Map(center=[-2, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# From the map we can see that there are two sampling locations in Uganda and one location in Kenya. Let's add these countries and investigate sample sizes.

# %%
ag3.count_samples(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']"
)
# Out:
# taxon                                                 arabiensis  gambiae  \
# country  admin1_iso admin1_name    admin2_name  year
# Kenya    KE-14      Kilifi         Kilifi North 2000           0       19
#                                                 2007           3        0
#                                                 2012          10        0
# Tanzania TZ-05      Kagera         Muleba       2015         137       32
#          TZ-13      Mara           Tarime       2012          47        0
#          TZ-25      Tanga          Muheza       2013           1       32
#          TZ-26      Manyara        Moshi        2012          40        0
# Uganda   UG-E       Eastern Region Tororo       2012          81      112
#          UG-W       Western Region Kanungu      2012           1       95
#
# taxon                                                 gcx3  unassigned
# country  admin1_iso admin1_name    admin2_name  year
# Kenya    KE-14      Kilifi         Kilifi North 2000     0           0
#                                                 2007     0           0
#                                                 2012    54           0
# Tanzania TZ-05      Kagera         Muleba       2015     1           0
#          TZ-13      Mara           Tarime       2012     0           0
#          TZ-25      Tanga          Muheza       2013    10           0
#          TZ-26      Manyara        Moshi        2012     0           0
# Uganda   UG-E       Eastern Region Tororo       2012     0           1
#          UG-W       Western Region Kanungu      2012     0           0

# %% [markdown]
# Let's also confirm how many cohorts would be available if we continued to use the "cohort_admin2_year" field to group by taxon, district and year.

# %%
ag3.sample_metadata(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']"
).groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# KE-14_Kilifi-North_arab_2007      3
# KE-14_Kilifi-North_arab_2012     10
# KE-14_Kilifi-North_gamb_2000     19
# KE-14_Kilifi-North_gcx3_2012     54
# TZ-05_Muleba_arab_2015          137
# TZ-05_Muleba_gamb_2015           32
# TZ-05_Muleba_gcx3_2015            1
# TZ-13_Tarime_arab_2012           47
# TZ-25_Muheza_arab_2013            1
# TZ-25_Muheza_gamb_2013           32
# TZ-25_Muheza_gcx3_2013           10
# TZ-26_Moshi_arab_2012            40
# UG-E_Tororo_arab_2012            81
# UG-E_Tororo_gamb_2012           112
# UG-W_Kanungu_arab_2012            1
# UG-W_Kanungu_gamb_2012           95
# dtype: int64

# %% [markdown]
# Here, sticking with a cohort size of 10 will allow us to include 3 cohorts from Kenya and 3 cohorts from Uganda.
#
# Let's now compute and plot diversity stats for all cohorts.

# %%
df_stats_tz_ke_ug_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_tz_ke_ug_admin2_year
# Out:
# [INFO] cohort (KE-14_Kilifi-North_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (KE-14_Kilifi-North_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
#                           cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0   KE-14_Kilifi-North_arab_2012  0.012515           0.012513   1.739748e-06
# 1   KE-14_Kilifi-North_gamb_2000  0.017751           0.017754  -3.812392e-06
# 2   KE-14_Kilifi-North_gcx3_2012  0.013473           0.013474  -1.341458e-06
# 3         TZ-05_Muleba_arab_2015  0.012306           0.012306   6.185033e-07
# 4         TZ-05_Muleba_gamb_2015  0.021242           0.021247  -4.337053e-06
# 5         TZ-13_Tarime_arab_2012  0.012435           0.012435  -3.120599e-07
# 6         TZ-25_Muheza_gamb_2013  0.017705           0.017705   4.563558e-07
# 7         TZ-25_Muheza_gcx3_2013  0.013395           0.013398  -2.958723e-06
# 8          TZ-26_Moshi_arab_2012  0.012374           0.012373   1.310417e-06
# 9          UG-E_Tororo_arab_2012  0.012560           0.012560   8.203444e-07
# 10         UG-E_Tororo_gamb_2012  0.021693           0.021698  -4.572455e-06
# 11        UG-W_Kanungu_gamb_2012  0.021464           0.021469  -4.432877e-06
#
#     theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0           0.000221         0.000868         0.012080         0.012947
# 1           0.000281         0.001103         0.017203         0.018306
# 2           0.000276         0.001082         0.012933         0.014015
# 3           0.000224         0.000877         0.011867         0.012744
# 4           0.000302         0.001182         0.020655         0.021838
# 5           0.000220         0.000861         0.012005         0.012866
# 6           0.000290         0.001136         0.017137         0.018273
# 7           0.000342         0.001340         0.012728         0.014068
# 8           0.000219         0.000857         0.011945         0.012801
# 9           0.000224         0.000876         0.012121         0.012998
# 10          0.000317         0.001244         0.021076         0.022320
# 11          0.000310         0.001214         0.020862         0.022076
#
#      theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0   0.015013          0.015010  ...        -0.649706  arabiensis  2012
# 1   0.018947          0.018950  ...        -0.213639     gambiae  2000
# 2   0.011567          0.011568  ...         0.814804        gcx3  2012
# 3   0.014789          0.014790  ...        -0.658653  arabiensis  2015
# 4   0.030350          0.030352  ...        -1.226721     gambiae  2015
# 5   0.015058          0.015059  ...        -0.681130  arabiensis  2012
# 6   0.018939          0.018935  ...        -0.218096     gambiae  2013
# 7   0.012917          0.012918  ...         0.257321        gcx3  2013
# 8   0.014669          0.014667  ...        -0.604319  arabiensis  2012
# 9   0.015198          0.015195  ...        -0.679454  arabiensis  2012
# 10  0.031458          0.031460  ...        -1.271359     gambiae  2012
# 11  0.030680          0.030685  ...        -1.225296     gambiae  2012
#
#         month   country  admin1_iso     admin1_name   admin2_name  longitude  \
# 0          -1     Kenya       KE-14          Kilifi  Kilifi North     39.909
# 1          -1     Kenya       KE-14          Kilifi  Kilifi North     39.909
# 2          -1     Kenya       KE-14          Kilifi  Kilifi North     39.909
# 3   [3, 4, 6]  Tanzania       TZ-05          Kagera        Muleba     31.621
# 4      [3, 6]  Tanzania       TZ-05          Kagera        Muleba     31.621
# 5           8  Tanzania       TZ-13            Mara        Tarime     34.199
# 6           1  Tanzania       TZ-25           Tanga        Muheza     38.948
# 7           1  Tanzania       TZ-25           Tanga        Muheza     38.948
# 8           8  Tanzania       TZ-26         Manyara         Moshi     37.308
# 9          10    Uganda        UG-E  Eastern Region        Tororo     34.026
# 10         10    Uganda        UG-E  Eastern Region        Tororo     34.026
# 11   [10, 11]    Uganda        UG-W  Western Region       Kanungu     29.701
#
#     latitude
# 0     -3.511
# 1     -3.511
# 2     -3.511
# 3     -1.962
# 4     -1.962
# 5     -1.431
# 6     -4.940
# 7     -4.940
# 8     -3.482
# 9      0.770
# 10     0.770
# 11    -0.751
#
# [12 rows x 31 columns]

# %%
plot_diversity_stats(df_stats_tz_ke_ug_admin2_year, color="taxon")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2d5a0956-5326-45c4-af7e-3ffb942b54d4" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d5a0956-5326-45c4-af7e-3ffb942b54d4")) {                    Plotly.newPlot(                        "2d5a0956-5326-45c4-af7e-3ffb942b54d4",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.000867714854960408,0.0008767828578080529,0.0008610896628349071,0.0008565317306298919,0.00087613073426833]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.01251345296362045,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi North",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.0011028237609669465,0.0011824588643770378,0.0011361997218875947,0.001243813749837042,0.0012142207472798142]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.017754352709839806,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0010819664826624746,0.001340143471567124]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"na ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8354efbb-ebb3-4346-8ede-b74c14be4e84" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8354efbb-ebb3-4346-8ede-b74c14be4e84")) {                    Plotly.newPlot(                        "8354efbb-ebb3-4346-8ede-b74c14be4e84",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0008870030015599784,0.0009732513776216025,0.000970944204637161,0.0009124973674744431,0.0009764560480252686]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.015010036298917529,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi North",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.0011189028489902808,0.0014784123971940866,0.0011770314504906054,0.0015843348168713888,0.0015673553606648687]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.018950259926004156,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009101509276341315,0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5a249520-6330-46f7-a452-c20b5b028eef" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a249520-6330-46f7-a452-c20b5b028eef")) {                    Plotly.newPlot(                        "5a249520-6330-46f7-a452-c20b5b028eef",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.09693761114943988,0.09298333949876054,0.10060131875886641,0.1045317786377764,0.09723784451490966]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[-0.698174737113276,-0.7051445660180288,-0.7314308240562268,-0.6565852582790553,-0.7280731615080003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi North",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.10264866548531008,0.06535341551175325,0.10950056994601906,0.06261572178375469,0.07113038634033975]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[-0.264963322235059,-1.2593981283459053,-0.2728466026281025,-1.3026667094156976,-1.260861549442583],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.24696927413833755,0.2021446790128285]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Ki ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bfbc6473-b540-4d7b-8bd3-de6f05210173" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfbc6473-b540-4d7b-8bd3-de6f05210173")) {                    Plotly.newPlot(                        "bfbc6473-b540-4d7b-8bd3-de6f05210173",                        [{"customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_x":{"array":[0.000867714854960408,0.0008767828578080529,0.0008610896628349071,0.0008565317306298919,0.00087613073426833]},"error_y":{"array":[0.0008870030015599784,0.0009732513776216025,0.000970944204637161,0.0009124973674744431,0.0009764560480252686]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.01251345296362045,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"xaxis":"x","y":[0.015010036298917529,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi North",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_x":{"array":[0.0011028237609669465,0.0011824588643770378,0.0011361997218875947,0.001243813749837042,0.0012142207472798142]},"error_y":{"array":[0.0011189028489902808,0.0014784123971940866,0.0011770314504906054,0.0015843348168713888,0.0015673553606648687]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi-North_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.017754352709839806,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"xaxis":"x","y":[0.018950259926004156,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi North",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0010819664826624746,0.001340143471567124]},"error_y":{"array":[0.0009101509276341315,0.0009724066834559926]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{custom ...

# %% [markdown]
# Some observations about these results:
#
# * All *An. arabiensis* cohorts show similar diversity. This indicates that all *An. arabiensis* populations from across this region share very similar demographic histories.
# * Diversity in *An. gambiae* from western Tanzania is very similar to both *An. gambiae* cohorts from Uganda. Conversely, diversity in *An. gambiae* from eastern Tanzania is very similar to *An. gambiae* from coastal Kenya. This supports a strong population division within *An. gambiae*, with different demographic histories.
# * Diversity is very similar between the two gcx3 cohorts from coastal Tanzania and Kenya. This indicates that the two gcx3 cohorts are sampled from populations with similar demographic histories. In particular, both cohorts have positive values for Tajima's D, which is consistent with a reduction in population size. We cannot infer the timing or strength of this reduction from Tajima's D alone, but it is interesting to note that these are the only two cohorts with evidence for population reduction, whereas all *An. gambiae* and *An. arabiensis* cohorts have negative Tajima's D, which is consistent with historical population expansion. This certainly adds evidence for an important distinction between the gcx3 taxon and other mosquito taxa in the region.

# %% [markdown]
# **Exercise 2 (English)**
#
# Rerun the diversity analysis for East Africa, adding Mozambique, Malawi and Mayotte. Discuss the patterns you observe with a colleague.
#
# **Exercice 2 (Français)**
#
# Réexécutez l'analyse de la diversité pour l'Afrique de l'Est, en ajoutant le Mozambique, le Malawi et Mayotte. Discutez des tendances que vous observez avec un collègue.

# %%
ag3.count_samples(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda', 'Mozambique', 'Malawi', 'Mayotte']")

ag3.sample_metadata(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda', 'Mozambique', 'Malawi', 'Mayotte']"
).groupby("cohort_admin2_year").size()

df_stats_tz_ke_ug_Mz_Ma_My_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda', 'Mozambique', 'Malawi', 'Mayotte']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_tz_ke_ug_Mz_Ma_My_admin2_year
# Out:
# [INFO] cohort (KE-14_Kilifi-North_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (KE-14_Kilifi-North_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Bandraboua_gamb_2011) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Bandraboua_gamb_2011) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Dembeni_gamb_2011) has insufficient samples (2) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Dembeni_gamb_2011) has insufficient samples (2) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Kani-Kéli_gamb_2011) has insufficient samples (7) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Kani-Kéli_gamb_2011) has insufficient samples (7) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Mtsamboro_gamb_2011) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Mtsamboro_gamb_2011) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Sada_gamb_2011) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Sada_gamb_2011) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (MYT_Tsingoni_gamb_2011) has insufficient samples (9) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MYT_Tsingoni_gamb_2011) has insufficient samples (9) for requested cohort size (10), dropping
# [INFO] cohort (MZ-I_Morrumbene_gamb_2003) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (MZ-I_Morrumbene_gamb_2003) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
#                           cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0   KE-14_Kilifi-North_arab_2012  0.012515           0.012513   1.739748e-06
# 1   KE-14_Kilifi-North_gamb_2000  0.017751           0.017754  -3.812392e-06
# 2   KE-14_Kilifi-North_gcx3_2012  0.013473           0.013474  -1.341458e-06
# 3        MW-S_Chikwawa_arab_2015  0.012257           0.012256   8.666643e-07
# 4      MZ-I_Morrumbene_gamb_2004  0.016380           0.016384  -3.135144e-06
# 5         TZ-05_Muleba_arab_2015  0.012306           0.012306   6.185033e-07
# 6         TZ-05_Muleba_gamb_2015  0.021242           0.021247  -4.337053e-06
# 7         TZ-13_Tarime_arab_2012  0.012435           0.012435  -3.120599e-07
# 8         TZ-25_Muheza_gamb_2013  0.017705           0.017705   4.563558e-07
# 9         TZ-25_Muheza_gcx3_2013  0.013395           0.013398  -2.958723e-06
# 10         TZ-26_Moshi_arab_2012  0.012374           0.012373   1.310417e-06
# 11         UG-E_Tororo_arab_2012  0.012560           0.012560   8.203444e-07
# 12         UG-E_Tororo_gamb_2012  0.021693           0.021698  -4.572455e-06
# 13        UG-W_Kanungu_gamb_2012  0.021464           0.021469  -4.432877e-06
#
#     theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0           0.000221         0.000868         0.012080         0.012947
# 1           0.000281         0.001103         0.017203         0.018306
# 2           0.000276         0.001082         0.012933         0.014015
# 3           0.000218         0.000856         0.011828         0.012684
# 4           0.000296         0.001161         0.015803         0.016964
# 5           0.000224         0.000877         0.011867         0.012744
# 6           0.000302         0.001182         0.020655         0.021838
# 7           0.000220         0.000861         0.012005         0.012866
# 8           0.000290         0.001136         0.017137         0.018273
# 9           0.000342         0.001340         0.012728         0.014068
# 10          0.000219         0.000857         0.011945         0.012801
# 11          0.000224         0.000876         0.012121         0.012998
# 12          0.000317         0.001244         0.021076         0.022320
# 13          0.000310         0.001214         0.020862         0.022076
#
#      theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0   0.015013          0.015010  ...        -0.649706  arabiensis  2012
# 1   0.018947          0.018950  ...        -0.213639     gambiae  2000
# 2   0.011567          0.011568  ...         0.814804        gcx3  2012
# 3   0.014285          0.014284  ...        -0.550035  arabiensis  2015
# 4   0.016431          0.016430  ...         0.046604     gambiae  2004
# 5   0.014789          0.014790  ...        -0.658653  arabiensis  2015
# 6   0.030350          0.030352  ...        -1.226721     gambiae  2015
# 7   0.015058          0.015059  ...        -0.681130  arabiensis  2012
# 8   0.018939          0.018935  ...        -0.218096     gambiae  2013
# 9   0.012917          0.012918  ...         0.257321        gcx3  2013
# 10  0.014669          0.014667  ...        -0.604319  arabiensis  2012
# 11  0.015198          0.015195  ...        -0.679454  arabiensis  2012
# 12  0.031458          0.031460  ...        -1.271359     gambiae  2012
# 13  0.030680          0.030685  ...        -1.225296     gambiae  2012
#
#         month     country  admin1_iso      admin1_name   admin2_name  \
# 0          -1       Kenya       KE-14           Kilifi  Kilifi North
# 1          -1       Kenya       KE-14           Kilifi  Kilifi North
# 2          -1       Kenya       KE-14           Kilifi  Kilifi North
# 3           5      Malawi        MW-S  Southern Region      Chikwawa
# 4   [2, 3, 4]  Mozambique        MZ-I        Inhambane    Morrumbene
# 5   [3, 4, 6]    Tanzania       TZ-05           Kagera        Muleba
# 6      [3, 6]    Tanzania       TZ-05           Kagera        Muleba
# 7           8    Tanzania       TZ-13             Mara        Tarime
# 8           1    Tanzania       TZ-25            Tanga        Muheza
# 9           1    Tanzania       TZ-25            Tanga        Muheza
# 10          8    Tanzania       TZ-26          Manyara         Moshi
# 11         10      Uganda        UG-E   Eastern Region        Tororo
# 12         10      Uganda        UG-E   Eastern Region        Tororo
# 13   [10, 11]      Uganda        UG-W   Western Region       Kanungu
#
#     longitude  latitude
# 0      39.909    -3.511
# 1      39.909    -3.511
# 2      39.909    -3.511
# 3      34.755   -15.933
# 4      35.299   -23.716
# 5      31.621    -1.962
# 6      31.621    -1.962
# 7      34.199    -1.431
# 8      38.948    -4.940
# 9      38.948    -4.940
# 10     37.308    -3.482
# 11     34.026     0.770
# 12     34.026     0.770
# 13     29.701    -0.751
#
# [14 rows x 31 columns]

# %% [markdown]
# ### Discussion
# - An. gambiae from western Tanzania (Muleba) show similar diversity with cohorts from Uganda (Tororo and Kanungu).
# - All the An. gambiae and An. arabiensis cohorts have a negative Tajima's D, indicating a population expansion, while the gcx3 cohorts have a positive Tajima's D, indicating population size reduction, and further demonstrates distinction from other mosquito taxa in the region.
# - An. gambiae cohorts from eastern Tanzania (Muheza), coastal Kenya (kilifi) and Mozambique (Morumbene) show similar diversity, similar demographic histories.
# - Hence there are 2 distinct An. gambiae populations with distinct demographic histories.
# - All the An. arabiensis cohorts show similar diversity, indicating shared similar demographic histories.
# - The gcx3 cohorts from coastal Kenya (Kilifi) and eastern Tanzani (Muheza) show similar diversity and are from similar demographic histories.

# %% [markdown]
# ### Example: Burkina Faso
#
# Finally, let's look at an example where we have data from the same location from multiple years, to illustrate how we might use diversity to monitor populations for signs of recent demographic changes.
#
# In Burkina Faso we have data from the Houet district from 2012 and 2014, for both *An. gambiae* and *An. coluzzii*.

# %%
ag3.count_samples(
    sample_query="country == 'Burkina Faso'"
)
# Out:
# taxon                                                   arabiensis  coluzzii  \
# country      admin1_iso admin1_name   admin2_name year
# Burkina Faso BF-07      Centre-Sud    Bazega      2004           0         0
#              BF-09      Hauts-Bassins Houet       2012           0        82
#                                                   2014           3        53
#
# taxon                                                   gambiae
# country      admin1_iso admin1_name   admin2_name year
# Burkina Faso BF-07      Centre-Sud    Bazega      2004       13
#              BF-09      Hauts-Bassins Houet       2012       99
#                                                   2014       46

# %% [markdown]
# **Exercise 3 (English)**
#
# Analyse diversity in Burkina Faso.
#
# Do you observe any differences between *An. gambiae* and *An. coluzzii*?
#
# Do you observe any differences between 2012 and 2014?
#
# **Exercice 3 (Français)**
#
# Analyser la diversité au Burkina Faso.
#
# Observez-vous des différences entre *An. gambiae* et *An. coluzzii*?
#
# Observez-vous des différences entre 2012 et 2014 ?

# %%
ag3.sample_metadata(
    sample_query="country in ['Burkina Faso']"
).groupby("cohort_admin2_year").size()

df_stats_Burkina_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Burkina Faso']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_Burkina_admin2_year
# Out:
# [INFO] cohort (BF-09_Houet_arab_2014) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anoph.base:cohort (BF-09_Houet_arab_2014) has insufficient samples (3) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
#                    cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0  BF-07_Bazega_gamb_2004  0.021858           0.021860      -0.000002
# 1   BF-09_Houet_colu_2012  0.022052           0.022056      -0.000003
# 2   BF-09_Houet_colu_2014  0.021929           0.021933      -0.000004
# 3   BF-09_Houet_gamb_2012  0.022312           0.022318      -0.000006
# 4   BF-09_Houet_gamb_2014  0.021936           0.021940      -0.000004
#
#    theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0          0.000318         0.001245         0.021238         0.022483
# 1          0.000321         0.001258         0.021427         0.022685
# 2          0.000325         0.001275         0.021295         0.022570
# 3          0.000316         0.001240         0.021699         0.022938
# 4          0.000310         0.001216         0.021332         0.022548
#
#     theta_w  theta_w_estimate  ...  tajima_d_ci_upp     taxon  year  \
# 0  0.032495          0.032490  ...        -1.341633   gambiae  2004
# 1  0.031699          0.031702  ...        -1.247966  coluzzii  2012
# 2  0.031076          0.031078  ...        -1.203671  coluzzii  2014
# 3  0.033551          0.033555  ...        -1.378013   gambiae  2012
# 4  0.032293          0.032294  ...        -1.315877   gambiae  2014
#
#        month       country  admin1_iso    admin1_name  admin2_name  longitude  \
# 0  [6, 7, 8]  Burkina Faso       BF-07     Centre-Sud       Bazega  -1.170000
# 1          7  Burkina Faso       BF-09  Hauts-Bassins        Houet  -4.356390
# 2          7  Burkina Faso       BF-09  Hauts-Bassins        Houet  -4.445170
# 3          7  Burkina Faso       BF-09  Hauts-Bassins        Houet  -4.290061
# 4          7  Burkina Faso       BF-09  Hauts-Bassins        Houet  -4.312283
#
#     latitude
# 0  12.060000
# 1  11.223768
# 2  11.233566
# 3  11.194657
# 4  11.206109
#
# [5 rows x 31 columns]

# %%
plot_diversity_stats(df_stats_Burkina_admin2_year, color="taxon")

# %% [markdown]
# ### Discussion
# - Both An. gambiae cohorts show similar diversity, have similar demographic history.
# - All the An. coluzzii and An. gambiae cohorts have a negative Tajima's D, indicating population expansion.
# - All the An. coluzzii cohorts in from Burkina Faso show similar diversity, indicating similar demographic history.
# - Divsersity is similar between An. gambiae and An. coluzzii cohorts, indicating close demographic history between the 2 taxa.

# %% [markdown]
# ## Well done!
#
# Well done for completing this module on genetic diversity summary statistics!
#
# ### Exercises
#
# Please now launch this notebook in colab, clear the outputs, copy it to your drive and run it from the top, complete the exercises you find along the way.
#
# ### Challenge (English)
#
# Choose any country or geographical region and perform comparative analysis of genetic diversity. Share your findings and conclusions with colleagues.
#
# ### Défi (Français)
#
# Choisissez n'importe quel pays ou région géographique et effectuez une analyse comparative de la diversité génétique. Partagez vos découvertes et conclusions avec vos collègues.
